# %%
import numpy as np
import pandas as pd

df= pd.read_csv('/content/winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
import tensorflow as tf

train_df= df.sample(frac=0.75, random_state=4)
val_df=df.drop(train_df.index)

# %%
train_df.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 289           11.6              0.42         0.53             3.3      0.105
# 962            6.6              0.57         0.02             2.1      0.115
# 826            7.5              0.27         0.34             2.3      0.050
# 495           10.7              0.35         0.53             2.6      0.070
# 57             7.5              0.63         0.12             5.1      0.111
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 289                 33.0                  98.0  1.00100  3.20       0.95
# 962                  6.0                  16.0  0.99654  3.38       0.69
# 826                  4.0                   8.0  0.99510  3.40       0.64
# 495                  5.0                  16.0  0.99720  3.15       0.65
# 57                  50.0                 110.0  0.99830  3.26       0.77
#
#      alcohol  quality
# 289      9.2        5
# 962      9.5        5
# 826     11.0        7
# 495     11.0        8
# 57       9.4        5

# %%
x_train=train_df.drop('quality', axis=1)
x_test=val_df.drop('quality', axis=1)
y_train=train_df['quality']
y_test=val_df['quality']
input_shape=[x_train.shape[1]]
input_shape
# Out:
# [11]

# %%
model=tf.keras.Sequential([tf.keras.layers.Dense(units=1,input_shape=input_shape)])
model.summary
# Out:
# <bound method Model.summary of <keras.src.engine.sequential.Sequential object at 0x7d690d658eb0>>

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(units=64,activation='relu',input_shape=input_shape),
    tf.keras.layers.Dense(units=64,activation='relu'),
    tf.keras.layers.Dense(units=1)
])
model.summary
# Out:
# <bound method Model.summary of <keras.src.engine.sequential.Sequential object at 0x7d690d408a00>>

# %%
model.compile(optimizer='adam', loss='mae')

# %%
losses = model.fit(x_train, y_train, validation_data=(x_test, y_test),batch_size=256, epochs=15)
# Out:
# Epoch 1/15
# 5/5 [==============================] - 2s 63ms/step - loss: 5.1833 - val_loss: 2.8136
# Epoch 2/15
# 5/5 [==============================] - 0s 11ms/step - loss: 3.2114 - val_loss: 2.4855
# Epoch 3/15
# 5/5 [==============================] - 0s 11ms/step - loss: 2.1530 - val_loss: 1.9762
# Epoch 4/15
# 5/5 [==============================] - 0s 11ms/step - loss: 1.8108 - val_loss: 1.1474
# Epoch 5/15
# 5/5 [==============================] - 0s 15ms/step - loss: 1.2480 - val_loss: 0.9333
# Epoch 6/15
# 5/5 [==============================] - 0s 17ms/step - loss: 1.0146 - val_loss: 0.7816
# Epoch 7/15
# 5/5 [==============================] - 0s 15ms/step - loss: 0.8304 - val_loss: 0.6518
# Epoch 8/15
# 5/5 [==============================] - 0s 13ms/step - loss: 0.7263 - val_loss: 0.6688
# Epoch 9/15
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6954 - val_loss: 0.6066
# Epoch 10/15
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6125 - val_loss: 0.5839
# Epoch 11/15
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5813 - val_loss: 0.5751
# Epoch 12/15
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5632 - val_loss: 0.5612
# Epoch 13/15
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5621 - val_loss: 0.5502
# Epoch 14/15
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5577 - val_loss: 0.5622
# Epoch 15/15
# 5/5 [==============================] - 0s 17ms/step - loss: 0.5486 - val_loss: 0.5429

# %%
model.predict(x_test.iloc[0:3, :])
# Out:
# 1/1 [==============================] - 0s 116ms/step
# array([[5.2482433],
#        [5.0252347],
#        [4.847066 ]], dtype=float32)

# %%
y_test.iloc[0:3]
# Out:
# 0     5
# 9     5
# 12    5
# Name: quality, dtype: int64

# %%
loss_df=pd.DataFrame(losses.history)
loss_df.loc[:,['loss','val_loss']].plot()
# Out:
# <Axes: >
